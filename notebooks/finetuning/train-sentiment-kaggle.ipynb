# %% [markdown]
# # Sentiment Classifier (Positive/Negative/Neutral)
#
# Fine-tunes VISOBert for Vietnamese social media sentiment analysis.

# %%
# 1. Setup
# !pip install -q transformers datasets scikit-learn rich

import torch
print(f"GPU: {torch.cuda.is_available()}")

# %%
# 2. Clone Repo
GITHUB_TOKEN = "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"
REPO_URL = f"https://{GITHUB_TOKEN}@github.com/GadGadGad/Real-time-Event-Detection-on-Social-Media-Data"

# !git clone {REPO_URL}
# %cd Real-time-Event-Detection-on-Social-Media-Data
# !mkdir -p data models

# %% [markdown]
# ### 3. Verify Data Distribution

# %%
# Data is pre-extracted from local pipeline runs
# !wc -l data/sentiment_train.jsonl

# Check distribution
import json
from collections import Counter
labels = []
with open('data/sentiment_train.jsonl') as f:
    for line in f:
        labels.append(json.loads(line)['label'])
print(Counter(labels))

# %% [markdown]
# ### 4. Train Classifier

# %%
# !python scripts/train/train_sentiment_classifier.py

# %% [markdown]
# ### 5. Export

# %%
# !rm -rf models/sentiment-classifier-vietnamese-v1/checkpoint-*
# !zip -r /kaggle/working/sentiment_classifier.zip models/sentiment-classifier-vietnamese-v1
print("Done! Download from Output pane.")
