# %% [markdown]
# # Reranker (Cross-Encoder) Fine-tuning & Comparison
#
# This notebook fine-tunes a Cross-Encoder and compares it against the base model to prove improvement.

# %%
# 1. Setup Environment
# !pip install -q sentence-transformers rich pandas

import torch
print(f"GPU Available: {torch.cuda.is_available()}")

# %%
# 2. Clone Repository
GITHUB_TOKEN = "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"
REPO_URL = f"https://{GITHUB_TOKEN}@github.com/GadGadGad/Real-time-Event-Detection-on-Social-Media-Data"

# !git clone {REPO_URL}
# %cd Real-time-Event-Detection-on-Social-Media-Data

# !mkdir -p data models

# %% [markdown]
# ### 3. Data Preparation
# We merge your annotated labels with the content to create positive and negative pairs.

# %%
# !python scripts/train/prepare_reranker_data.py

# Check stats
# !wc -l data/reranker_train.jsonl

# %% [markdown]
# ### 4. Train Reranker
# Fine-tuning `cross-encoder/ms-marco-MiniLM-L-6-v2` for 3 epochs.

# %%
# !python scripts/train/train_reranker.py

# %% [markdown]
# ### 5. Compare Base vs Tuned Model
# This script will show you side-by-side why the tuned model is better.

# %%
# !python scripts/eval/compare_reranker.py

# %% [markdown]
# ### 6. Export
# Zip the model for download.

# %%
# !zip -r /kaggle/working/reranker_model.zip models/reranker-vietnamese-v1
print("✅ Model zipped to /kaggle/working/reranker_model.zip. You can download it from the Output pane.")
