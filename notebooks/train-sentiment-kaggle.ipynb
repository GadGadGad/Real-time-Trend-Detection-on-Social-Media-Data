# %% [markdown]
# # Sentiment Classifier Training
#
# Train a Positive/Negative classifier for Vietnamese social media.

# %%
# !pip install -q transformers datasets scikit-learn rich
import torch
print(f"GPU: {torch.cuda.is_available()}")

# %%
GITHUB_TOKEN = "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"
# !git clone https://{GITHUB_TOKEN}@github.com/GadGadGad/Real-time-Event-Detection-on-Social-Media-Data
# %cd Real-time-Event-Detection-on-Social-Media-Data
# !mkdir -p data models

# %%
# Data already pushed, just verify
# !wc -l data/sentiment_train.jsonl

# %%
# !python scripts/train/train_sentiment_classifier.py

# %%
# !zip -r /kaggle/working/sentiment_classifier.zip models/sentiment-classifier-vietnamese-v1
print("Done! Download from Output.")
