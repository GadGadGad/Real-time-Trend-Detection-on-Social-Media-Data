# %%
# !pip install protonx

# %% [markdown]
# ### Ứng dụng thư viện này vào xây dựng Chatbot có [độ chính xác cao](https://colab.research.google.com/drive/1t7Do6pj6lxUPxxwTyD_GtuNNNV6mtXLf?usp=sharing)

# %%
from protonx import ProtonX

# %% [markdown]
# #### Bạn hãy lấy Access Token của mình [ở đây](https://platform.protonx.io/).

# %%
import os
os.environ["PROTONX_API_KEY"] = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6InByb3RvbnhzbWFydGVkaXRvckBnbWFpbC5jb20iLCJpYXQiOjE3NTk5ODA4NzIsImV4cCI6MTc2MjU3Mjg3Mn0.ORkYcSLoRcI_OLb_fjyR3c9tTuRuF6LNyYNRtnxGekQ"

# %%
client = ProtonX()

client.embeddings.create("Tôi yêu Việt Nam đắm say hihi!!!")
# Out:
# {'data': [{'index': 0,
#    'embedding': [-0.025539232417941093,
#     0.05843506380915642,
#     0.005219548474997282,
#     -0.03857657313346863,
#     -0.0346938855946064,
#     -0.06476195156574249,
#     -0.04120450094342232,
#     0.03352146968245506,
#     0.03254825249314308,
#     -0.04805484786629677,
#     0.01807720959186554,
#     -0.03193565085530281,
#     -0.09851111471652985,
#     0.04348979890346527,
#     -0.08683732897043228,
#     0.04461421072483063,
#     0.032408569008111954,
#     0.01172727346420288,
#     0.018336737528443336,
#     0.032734859734773636,
#     0.07748036086559296,
#     0.012487635016441345,
#     -0.0147565808147192,
#     0.10824432969093323,
#     0.010954594239592552,
#     0.014941398054361343,
#     0.0895814448595047,
#     -0.06418506801128387,
#     -0.07456984370946884,
#     -0.026163998991250992,
#     -0.07931633293628693,
#     -0.03469815477728844,
#     -0.008640706539154053,
#     0.004035495221614838,
# ...

# %% [markdown]
# Batch Processing

# %%
client.embeddings.create(input=[
    "Tôi yêu Việt Nam đắm say!!!",
    "Tôi là người Việt Nam"
])

# %% [markdown]
# Times Benchmarks

# %%
# @title Time Benchmarks
def displayTime(time):
    display(HTML(f"""
        <div style='font-size:20px; font-weight:bold; color:red'>
            Time taken: {time} ms
        </div>
        <div style='font-size:20px; font-weight:bold; color:blue'>
            Only CPUs
        </div>
    """))

# %%
import time
from protonx import ProtonX

text = "Tôi yêu Việt Nam đắm say hihi!!! Tôi rất vui khi ra mắt chào mừng ngày 2/9"

start_time = time.time()

embedding = client.embeddings.create(text)

end_time = time.time()

print("Embedding:", embedding)
displayTime((end_time - start_time) * 1000)
# Out:
# Embedding: {'data': [{'index': 0, 'embedding': [-0.0067747426219284534, 0.06783780455589294, -0.023650087416172028, -0.04027293622493744, -0.02417009510099888, -0.023517513647675514, -0.03594445437192917, 0.041246943175792694, 0.029133856296539307, -0.046776141971349716, -0.04090893641114235, -0.015556790865957737, -0.07368439435958862, 0.013761776499450207, -0.08807232975959778, 0.02513306401669979, 0.05473991110920906, 0.02279827371239662, 0.04706650227308273, 0.030181631445884705, 0.04992809146642685, -0.019089581444859505, -0.017999136820435524, 0.09865988045930862, 0.02081250213086605, 0.048305004835128784, 0.06356292963027954, -0.060471102595329285, -0.051357705146074295, -0.023297175765037537, -0.11013410240411758, -0.02487691305577755, -0.005421264097094536, 0.060478754341602325, 0.044164422899484634, -0.021663684397935867, -0.005698650609701872, 0.02114424854516983, -0.048728685826063156, -0.014002733863890171, -0.021597454324364662, -0.03368093818426132, -0.0343300253152847
# ...
